# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import openpyxl
from time import sleep
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# # 데이터 정리용 Excel open/make
# try:
#     wb = openpyxl.load_workbook('insta_data_sep.xlsx')
#     sheet = wb.activate
#     print('Open Complete')
# except:
#     wb = openpyxl.Workbook()
#     sheet = wb.active
#     print('Make Complete')

# %%
def tag_collector(body):
    wordlist = []
    for word in body:
        if word[0] =='#':
            length = len(word)
            #특문 제거
            for i in range(1,length):
                if 33 <= ord(word[i]) and ord(word[i]) < 35:
                    if word[i+1:] != '':
                        body.append(word[i+1:])
                    word = word[:i]
                    break
                elif 36 <= ord(word[i]) and ord(word[i]) <= 47:
                    if word[i+1:] != '':
                        body.append(word[i+1:])
                    word = word[:i]
                    break
                elif 58 <= ord(word[i]) and ord(word[i]) <= 64:
                    if word[i+1:] != '':
                        body.append(word[i+1:])
                    word = word[:i]
                    break
                elif 91 <= ord(word[i]) and ord(word[i]) <= 96:
                    if word[i+1:] != '':
                        body.append(word[i+1:])
                    word = word[:i]
                    break
                elif 123 <= ord(word[i]) and ord(word[i]) <= 126:
                    if word[i+1:] != '':
                        body.append(word[i+1:])
                    word = word[:i]
                    break
                else:
                    continue

            # 붙어있는 해쉬태그 분리, 혹은 수집
            if word.count('#') >= 2:
                word = word.split('#')
                wordlist += word
            else:
                wordlist.append(word[1:])
        # 해쉬태그 아니면 스킵
        else: 
            continue
    # 공백 제거        
    null_cnt = wordlist.count('')
    if null_cnt !=0:
        for i in range(null_cnt):
            wordlist.remove('')
    return wordlist

# %%
keywords = ['에스콰이어코리아']

#url = 'https://www.instagram.com'
#url = 'https://www.instagram.com/accounts/login/?source=auth_switcher'
#driver = webdriver.Chrome("/Users/azmosady/Desktop/chromedriver")
#driver.implicitly_wait(5)
#driver.get(url)
#ID
#PW
#driver.find_element_by_link_text('Log in').click()
#sleep(1)
#driver.find_element_by_name('username').send_keys(ID)
#driver.find_element_by_name('password').send_keys(PW)
#driver.find_element_by_css_selector('button._0mzm-.sqdOP.L3NKy').click()
#driver.find_element_by_css_selector('button.aOOlW.HoLwm').click()


# 검색
#driver.find_element_by_css_selector('input.XTCLo.x3qfX').send_keys('#'+keyword)
#driver.find_element_by_xpath('//a[@href="/explore/tags/'+keyword+'/"]').click()

#sleep(1)
#driver.find_element_by_css_selector("div.v1Nh3").click()
#for i in driver.find_elements_by_css_selector('a'):
for keyword in keywords:
    driver = webdriver.Chrome("/Users/azmosady/Desktop/chromedriver")
    url = "https://www.instagram.com/explore/tags/"+keyword+'/'
    driver.get(url)
    sleep(3)
    driver.find_element_by_css_selector("div.v1Nh3").click()
    listnum = 0
    while True:
        try:
            print("="*40)
            sleep(1.5)
            # 본문 읽어오기
            body = driver.find_element_by_css_selector("div.C4VMK>span").text
            body = body.split()
            print(listnum,tag_collector(body))
            listnum+=1
            #sleep(1)
            driver.find_element_by_css_selector("a.HBoOv").click()
        except:
            print('out')
            driver.close()
            break;
# Out:
# ========================================
# 0 ['latintohangul', 'esquire', 'esquiremagazine', '에스콰이어', '에스콰이어코리아', '한글날', '한글', '한글디자인', '한글날', '한글디자이너', '타입디자이너', '글자디자이너', 'hangul', 'hangeul', 'hanguldesign', 'hangeuldesign', 'typedesigner']
# ========================================
# 1 ['esquire', '잡지', '매거진', 'illustration', 'drawing', 'pendrawing', 'kimchankyum', '그림', '펜화', '시계', '컬럼', 'art', '일러스트', '삽화', '작업', '에스콰이어코리아', 'daily', '일상']
# ========================================
# 2 ['에콰티비', '에스콰이어코리아', '라이브', '콘서트', 'Concert', '박재정', '다시태어날수있다면', 'IfOnly', '박재정노랫말', '노랫말', '앨범', 'Title', '정동환', 'parcjaejung', 'esquirekorea', 'phonecert', '박재정발라드', '노래추천', 'kpop', '음스타그램']
# ========================================
# 3 ['박재범', 'JayPark', '에스콰이어코리아', 'esquirekorea', 'AOMG']
# ========================================
# 4 ['오혁', '혁오', 'ohhyuk', '에스콰이어코리아']
# ========================================
# 5 ['Repost', '박서준', 'PARKSEOJUN', 'esquirekorea', '에스콰이어코리아', '박서준', 'parkseojun', '朴敘俊', 'パクソジュン', 'parkseojoon', '朴叙俊']
# ========================================
# 6 ['kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 7 ['에스콰이어코리아', 'esquirekorea', '2018년', '2월호', '커버스토리', '손예진', '2018', 'february', 'cover']
# ========================================
# 8 ['에스콰이어코리아', '에스콰이어', '라이언', 'esquirekorea', 'esquire', 'kakaoryan', 'seoulryan', 'ryan']
# ========================================
# 9 ['클럽에스콰이어x휴고보스', '직장인취미', '스튜디오로우', '소통해요', '맞팔해요', '포토샵학원', '직장인스타그램', '직장인모임', '강남포토샵', '포토샵강좌', '직장인동호회', '포토샵과외', '일러스트과외', '일상그램', '디자인과외', '소통해요우리', '선팔하면맞팔가요', '선팔하면맞팔🙆', '디자인클래스', '좋아요반사❤️', '좋아요반사', '포토샵배우기', '선팔하면맞팔', '패션포트폴리오수업', '클럽에스콰이어', '휴고보스', '인플루언서', '에스콰이어코리아', '클럽에스콰이어인사이트파티', '에스콰이어']
# ========================================
# 10 ['에스콰이어코리아', '휴고보스', '감파리는사랑입니다❤️']
# ========================================
# 11 ['에스콰이어코리아', '클럽에스콰이어', '에스콰이어인사이트파티', '휴고보스', '라이즈호텔']
# ========================================
# 12 ['esquirekorea', 'hugoboss', 'party', '에스콰이어코리아', '휴고보스', '파티', '베스트드레스', 'bestdresser', 'rysehotel', '라이즈오토그래프컬렉션', 'clubesquire', '클럽에스콰이어', '클럽에스콰이어x휴고보스', '19fw', '수트', 'suit']
# ========================================
# 13 ['클럽에스콰이어x휴고보스', '직장인취미', '스튜디오로우', '소통해요', '맞팔해요', '포토샵학원', '직장인스타그램', '직장인모임', '강남포토샵', '포토샵강좌', '직장인동호회', '포토샵과외', '일러스트과외', '일상그램', '디자인과외', '소통해요우리', '선팔하면맞팔가요', '선팔하면맞팔🙆', '디자인클래스', '좋아요반사❤️', '좋아요반사', '포토샵배우기', '선팔하면맞팔', '패션포트폴리오수업', '클럽에스콰이어', '휴고보스', '인플루언서', '에스콰이어코리아', '클럽에스콰이어인사이트파티', '에스콰이어']
# ========================================
# 14 ['클럽에스콰이어x휴고보스', '직장인취미', '스튜디오로우', '소통해요', '맞팔해요', '포토샵학원', '직장인스타그램', '직장인모임', '강남포토샵', '포토샵강좌', '직장인동호회', '포토샵과외', '일러스트과외', '일상그램', '디자인과외', '소통해요우리', '선팔하면맞팔가요', '선팔하면맞팔🙆', '디자인클래스', '좋아요반사❤️', '좋아요반사', '포토샵배우기', '선팔하면맞팔', '포토샵클래스', '패션포트폴리오수업', '클럽에스콰이어', '휴고보스', '인플루언서', '에스콰이어코리아', '클럽에스콰이어인사이트파티']
# ========================================
# 15 ['에스콰이어코리아', '에스콰이어인사이트파티', 'rysehotel', '휴고보스', '클럽에스콰이어x휴고보스']
# ========================================
# 16 []
# ========================================
# 17 ['kikokostadinov', '키코코스타디노프', '메신저백', 'messengerbag', '공포물', '가방스타그램', '공포스타그램', '인싸템', '세젤힙', '에스콰이어', '에스콰이어코리아', 'esquire', 'ESQUIREKOREA']
# ========================================
# 18 ['메르세데스벤츠', 'mercedesbenz', 'gle', 'thenewgle', 'allkindofstrength', '더뉴gle', 'gle300d', 'gle55amg', '자동차', '카스타그램', '신차', 'suv', 'sav', '액티브라이프', '에스콰이어코리아', '에디터스팩토리', '자동차저널리스트김태영']
# ========================================
# 19 ['박재정은잘되어야한다', '에스콰이어코리아', 'magazine', '박재정', '그림', '박재정그림', '박재정팬아트', '그림', '그림스타그램', '그림그램', '낙서', '낙스타그램', '일러스트', '일러스트레이션', 'illustration', 'Parcjaejung', 'fanart']
# ========================================
# 20 ['ralphlauren', 'marcjacobs', 'ootd', 'mensfashion', 'menswear', 'style', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '클라제tv', 'clazetv', '옷스타그램', '패션', '패션피플', '남성패션', '데일리룩', 'esquirekorea', '에스콰이어코리아', '에스콰이어', 'esquiremagazine', '비오는날', 'rainyday']
# ========================================
# 21 ['에스콰이어코리아', 'esquirekorea']
# ========================================
# 22 ['에스콰이어코리아', 'esquirekorea']
# ========================================
# 23 ['ralphlauren', 'ninaricci', 'h', 'uniqlo', 'mensfashion', '스타일', 'menswear', 'clazetv', 'ootd', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '에스콰이어코리아', '옷스타그램', '패션', '패션피플', '남성패션', '데일리룩', 'esquirekorea', 'esquiremagazine', '현빈', '에스콰이어9월호']
# ========================================
# 24 ['kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama', 'regrann']
# ========================================
# 25 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 26 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 27 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 28 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 29 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 30 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 31 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 32 ['ralphlauren', 'allanedmonds', 'uniqlo', 'mensfashion', 'menswear', 'clazetv', 'ootd', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '에스콰이어코리아', '옷스타그램', '패션', '패션피플', '남성패션', 'moma', '데일리룩']
# ========================================
# 33 ['Repost', 'kimjaewook', '김재욱', '스타패션', '던힐', 'DUNHILL', 'dunhillfall2019', 'esquirekorea', '에스콰이어코리아', 'kfashion', 'kstyle', 'kimjaewookstyle', 'kimjaewookfashion', '셀럽패션', '셀럽스타일', '연예인패션', '연예인착용', '연예인스타일', '김재욱패션', '김재욱스타일', '패션정보', 'kdrama']
# ========================================
# 34 ['첫줄', '첫줄좋반', '선팔하면맞팔', '추억', '소래포구', '월곶포구', '바다', '바다스타그램', '소래대교', '인천', '인천여행', '바다여행', '풍경스타그램', '에스콰이어', '에스콰이어송천', '에스콰이어전주송천', '에스콰이어전주', '에스콰이어코리아', '전주여행', '전주신발', '전주구두', '전주신시가지', '신시가지', '효자동', '송천동', '전주', '순천', '여수', '전주스타그램', '여행스타그램']
# ========================================
# 35 ['lansmere', 'allanedmonds', 'uniqlo', 'mensfashion', 'menswear', 'clazetv', 'ootd', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '에스콰이어코리아', '옷스타그램', '패션', '패션피플', '남성패션']
# ========================================
# 36 ['우리집', '벌새', '윤가은', '김보라', '에스콰이어코리아', 'esquirekorea']
# ========================================
# 37 ['repost', '던힐', '알프레드던힐', 'dunhill', 'alfreddunhill', '김재욱', 'kimjaeuck', '김재욱', '김재욱배우님', '김재욱앓이', 'kimjaewook', 'kimjaeuck', '金材昱', 'キムジェウク', '에스콰이어', '에스콰이어코리아', 'esquire', 'esquirekorea', '화보']
# ========================================
# 38 ['mensfashion', 'mensfashionmagazie', 'magazine', 'esquire', 'esquiremagazine', 'esquirekorea', 'gq', 'gqmagazine', 'gqmagazinekorea', 'arena', 'arenamagazjne', 'menshealth', 'menshealthkorea', '에스콰이어', '에스콰이어코리아', '지큐', '지큐코리아', '아레나', '아레나코리아', '멘즈헬스', '멘즈헬스코리아']
# ========================================
# 39 ['에스콰이어코리아', 'esquirekorea', '김재욱', '엠버리우']
# ========================================
# 40 ['mensfashion', 'menswear', 'clazetv', 'ootd', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '에스콰이어코리아', '옷스타그램', '클래식패션', 'classicfashion', 'koreanmenstyle', '스타일', '패피', 'cantarelli', '패션피플', '남자패션스타일']
# ========================================
# 41 ['mensfashion', 'menswear', 'clazetv', 'ootd', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '에스콰이어코리아', '옷스타그램', '클래식패션', 'classicfashion', 'koreanmenstyle', '스타일', '패피', 'cantarelli', '패션피플', '남자패션스타일']
# ========================================
# 42 ['배우성훈', '성훈', 'sunghoon', '락포트', '에스콰이어코리아']
# ========================================
# 43 ['현빈', '현빈사랑해요', '김태평', 'ヒョンビン', 'hyunbin', '玄彬', '에스콰이어코리아']
# ========================================
# 44 ['슬기', 'seulgi', '레드벨벳', 'redvelvet']
# ========================================
# 45 ['슬기', 'seulgi', '레드벨벳', 'redvelvet', '에스콰이어코리아', 'esquirekorea']
# ========================================
# 46 ['현빈']
# ========================================
# 47 ['mensfashion', 'menswear', 'clazetv', 'ootd', 'ralphlauren', 'zico', 'cos', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '에스콰이어코리아', '옷스타그램', '패션스타그램', '패션피플']
# ========================================
# 48 ['mensfashion', 'menswear', 'clazetv', 'ootd', 'ralphlauren', 'marcjacobs', 'rolexdatejust', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 49 ['현빈', '현빈사랑해요', '김태평', 'ヒョンビン', 'hyunbin', '玄彬', '에스콰이어코리아']
# ========================================
# 50 ['에스콰이어코리아', '에스콰이어', '현빈', '현빈사랑해요', '김태평', 'ヒョンビン', 'hyunbin', '玄彬', '9월호']
# ========================================
# 51 ['clazetv', 'ootd', 'ralphlauren', 'tods', 'louisvuitton', 'mensfashion', '출근룩', 'menswear', 'clazetv', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 52 ['clazetv', 'ootd', 'mensfashion', 'ralphlauren', 'allenedmonds', '퇴근룩', 'menswear', 'clazetv', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 53 []
# ========================================
# 54 ['ootd', 'mensfashion', 'acnestudios', 'zara', 'isabelmarant', 'menswear', 'mensweardaily', 'clazetv', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 55 ['ootd', 'mensfashion', 'ralphlauren', 'marni', 'tods', 'mulberry', 'menswear', '출근룩', 'mensweardaily', 'clazetv', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 56 ['ootd', 'mensfashion', 'menstyle', 'louisvuitton', 'marcjacobs', 'clazetv', 'menswear', 'mensweardaily', 'clazetv', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 57 ['ootd', 'mensfashion', 'jwanderson', 'marcjacobs', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 58 ['ootd', 'mensfashion', 'marni', 'zara', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 59 ['ootd', 'mensfashion', 'ralphlauren', 'zara', 'allenedmonds', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 60 ['ootd', 'mensfashion', 'burberry', 'zara', 'gucci', '일상', '오오티디', '일상스타그램', '출근룩', 'daily', '클라제', '강남역', '에스콰이어코리아', '옷스타그램']
# ========================================
# 61 ['좁은방', '김흥모', '에스콰이어코리아', '켄짱과고양이', '네코마키', '노견일기', '정우열', '박막례이대로죽을순없다', '안녕', '안녕달', '평등은개뿔', '보통은이렇게살고있습니다', '빵이', '무슨일이일어났는지는아무도', '김영하', '여자혼자떠나는교토산책', '웃는가족', '이순구의웃는얼굴']
# ========================================
# 62 ['rain', 'fashionicon', 'Repost', '에스콰이어', 'esquire', '화보모델', '배우정지훈', '가수비', 'rain', 'therain', '비', '멋진남자', '에스콰이어코리아', '다음행보도기대됩니다']
# ========================================
# 63 ['balenciaga', 'ohhyuk', 'hyukoh', '오혁', '혁오', '발렌시아가', '에스콰이어', '에스콰이어8월호', '에스콰이어코리아']
# ========================================
# 64 ['modalabseoul', '모다랩', '고간지', '고등학생간지대회', '에스콰이어', '에스콰이어코리아', '패션스쿨', '패션과']
# ========================================
# 65 []
# ========================================
# 66 ['오혁', 'ohhyuk']
# ========================================
# 67 ['첫줄', '첫줄좋반', '좋아요', '좋아요반사', '선팔하면맞팔', '선팔', '맞팔', '태풍', '태풍다나스', '다나스', '제주', 'Jeju', '비', '전주', '전주신시가지', '신시가지', '롯데마트송천점', '에스콰이어코리아', '에스콰이어송천', '에스콰이어', 'ESQUIRE', '바다스타그램', '날씨스타그램', '제주스타그램']
# ========================================
# 68 ['비로인한조기퇴근', '여유', '에스콰이어코리아', '7월감성']
# ========================================
# 69 ['첫줄', '첫줄좋반', '좋아요', '좋아요반사', '좋반', '선팔하면맞팔', '선팔', '맞팔', '삼겹살', '목살', '먹스타그램', '고기스타그램', '맛스타그램', '저녁스타그램', '저녁', '고기', '전주신시가지', '신시가지', '에스콰이어', '에스콰이어전주송천', '에스콰이어코리아', '전주', '전주신발', '여자신발', '남자신발', '여자구두', '남자구두', '구두', '신발스타그램']
# ========================================
# 70 ['첫줄', '첫줄반사', '첫줄좋반', '좋아요', '좋아요반사', '에스콰이어', '에스콰이어코리아', '에스콰이어전주송천', 'ESQUIRE', '롯데마트', '롯데마트송천점', '전주롯데마트', '전주', 'JEONJU', '전주여행', '전주쇼핑', '쇼핑스타그램', '전주신발', '구두스타그램', '신발스타그램', '전주신시가지', '신시가지', '알림스타그램']
# ========================================
# 71 ['첫줄', '첫줄좋반', '좋아요반사', '좋아요', '선팔하면맞팔', '선팔', '맞팔', '에스콰이어', '에스콰이어전주송천', '에스콰이어코리아', 'ESQUIRE', '전주', '전주신시가지', '신시가지', '여행', '전주신발', '신발', '신발스타그램', '구두', '구두스타그램', '데일리', '데일리슈즈', '가격문의DM']
# ========================================
# 72 ['첫줄', '첫줄좋반', '좋반', '마카롱', '먹스타그램', '마카롱스타그램', '전주', '전주송천', '송천동', '전주신발', '전주구두', '구두', '구두추천', '구두스타그램', '신발스타그램', 'ESQUIRE', '에스콰이어', '에스콰이어전주송천', '에스콰이어코리아', '롯데마트송천점']
# ========================================
# 73 ['박재정커버곡', '박재정', '바람이분다', 'cover', '에콰티비', '에스콰이어코리아', 'phonecert', '폰서트', 'Concert', '가수', '박재정', '노랫말', 'parcjaejung', 'mysticstory', 'kpop', 'musician', 'esquire', 'esquirekorea', 'music', 'song', '박재정발라드', '노래추천', '음스타그램', 'instamusic', 'Phone']
# ========================================
# 74 ['이승찬', 'seungchan', 'esquirekorea', 'esquire', '에스콰이어', '에스콰이어코리아', '6월', '화보', 'pictorial', 'june', 'model', 'fashion', '모델', '패션', 'ygkplus', 'milkmodels', 'crewmodels', '남자모델', 'malemodel', 'menmodel', '인물', 'portrait', 'pure', 'innocent', '케이플러스', '얼굴', '이미지', '깨끗함']
# ========================================
# 75 ['박재정은잘되어야한다', '에스콰이어코리아', 'magazine', '가수', '박재정', '다시태어날수있다면', '미스틱박재정', '박재정앨범', '비쥬얼가수', '박재정미니앨범', '노랫말', '박재정노랫말', '케이팝', '발라드', '음스타그램', '송스타그램', '발라더', '고막남친', '감성발라드', '발라드추천', '발라드가수', '정통발라드', '7월발매신곡', '명품발라더', 'Parcjaejung', 'ballade', 'kpop', 'singer', 'newalbum', 'minialbum']
# ========================================
# 76 ['Baccarat', '무더위', '여름', '폭염', '폭염주의', '더위', '낮술', '술', '금요일', '불금', '에스콰이어', 'ESQUIREKOREA', '바카라', '바카라크리스털', '바카라크리스탈', '크리스탈', '크리스털', '바카라브랜드', '바카라코리아', '하이볼', 'BaccaratCrystal', 'Crystal', 'Baccaratkorea', '매거진', '에스콰이어코리아', '에스콰이어매거진', '화보', '리그램', 'Regram']
# ========================================
# 77 ['Baccarat', '무더위', '여름', '폭염', '폭염주의', '더위', '낮술', '술', '금요일', '불금', '에스콰이어', 'ESQUIREKOREA']
# ========================================
# 78 ['파가니니', '카프리스24번', '바이올리니스트', '양인모', '에스콰이어코리아', '최애곡']
# ========================================
# 79 ['Baccarat', '무더위', '여름', '폭염', '폭염주의', '더위', '낮술', '술', '금요일', '불금', '에스콰이어', 'ESQUIREKOREA', '바카라', '바카라크리스털', '바카라크리스탈', '크리스탈', '크리스털', '바카라브랜드', '바카라코리아', '코스터', 'BaccaratCrystal', 'Crystal', 'Baccaratkorea', '매거진', '에스콰이어코리아', '에스콰이어매거진', '화보', '리그램', 'Regram']
# ========================================
# 80 ['Baccarat', '무더위', '여름', '폭염', '폭염주의', '더위', '낮술', '술', '금요일', '불금', '에스콰이어', 'ESQUIREKOREA']
# ========================================
# 81 ['박재범', 'jaypark']
# ========================================
# 82 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 83 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 84 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 85 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 86 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 87 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 88 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 89 ['변준서', '에스콰이어', '에스콰이어코리아', '에이코닉', 'aconic', '스탤리온엔터테인먼트', 'stallionentertainment', 'modeltainer', 'koreanmodel', 'model', 'fashionmodel', 'fashion', 'pictorial', '모델테이너', '모델', '패션모델', '모델테인먼트', '화보', '광고', 'magazine', '매거진', 'fashion', '한국모델']
# ========================================
# 90 ['Repost', '박재범', 'JayPark', 'esquirekorea', '에스콰이어코리아', 'AOMG', 'sexy4eva', '💜']
# ========================================
# 91 ['박재범', 'JayPark', 'esquirekorea', '에스콰이어코리아', 'AOMG']
# ========================================
# 92 ['강한남자', '멋진남자', '에스콰이어코리아', '스트롱바이줌바', '홍보대사', '브라이언', '플라이투더스카이', 'brianjoo', 'flytothesky']
# ========================================
# 93 ['이엘', 'esquire', 'esquirekorea', '에스콰이어', '에스콰이어코리아', '2월', '이미스로브', 'emis로브', '이미스', 'emis', '로브', '후리스로브']
# ========================================
# 94 ['mizangwonbytaehyun', '미장원by태현', '미장원바이태현', 'hair', 'kpop', '태현쌤', '미애쌤', '청담동', '헤어메이크업', '청담동미용실', '연예인미용실', '연예인헤어', '연예인메이크업', '연예인네일', 'Repost', '박재범', 'JayPark', '에스콰이어코리아', 'esquirekorea', 'AOMG']
# ========================================
# 95 ['박재범', 'JayPark', 'aomg', 'h1ghrmusic', 'boss', 'theroadlesstraveled', 'rocnation', 'jwalkerz', '에스콰이어코리아', 'esquirekorea']
# ========================================
# 96 ['박재범', 'JayPark', 'aomg', 'h1ghrmusic', 'boss', 'theroadlesstraveled', 'rocnation', 'jwalkerz', '에스콰이어코리아', 'esquirekorea']
# ========================================
# 97 ['박재범', 'JayPark', '에스콰이어코리아', 'esquirekorea', 'AOMG']
# ========================================
# 98 ['박재범', 'jaypark', '에스콰이어코리아']
# ========================================
# 99 ['시티포레스티벌2019', '말왕TV', '장인성선수', '이현진선수', '시티포레스티벌', '비비큐', '비비큐치킨', '질스튜어트스포츠', '수려한', '주짓수', '수영', '에스콰이어코리아', '에스콰이어', 'cityforestival', 'cityforestival2019', 'BBQ', 'esquirekorea']
# ========================================
# 100 ['썸씽로튼', '초대이벤트', '에스콰이어코리아']
# ========================================
# 101 ['현정', '현아', '초삼이', '유딩이', '책', '잡지', '뚜르드몽드', '에스콰이어코리아', '좋은생각', '육아스타그램', '딸스타그램', '자매스타그램', '책스타그램', '줌마그램', '일상', '일산댁', '딸둘맘', '책읽는엄마']
# ========================================
# 102 ['ph1', '피에이치원', '박준원', '하이어뮤직', '에스콰이어코리아', '에콰티비']
# ========================================
# 103 ['나인오파이브']
# ========================================
# 104 ['박현재', '모델박현재', '국민대평생교육원', '국민대학교평생교육원', '연극학전공', '모델연기', '국민대평생교육원모델연기', '패션모델', 'model', '에스콰이어', '에스콰이어코리아', '커머스모델', '남자모델', '화보', '지면화보', '패션화보', '패션매거진']
# ========================================
# 105 ['박현재', '모델박현재', '국민대평생교육원', '국민대학교평생교육원', '연극학전공', '모델연기', '국민대평생교육원모델연기', '패션모델', 'model', '에스콰이어', '에스콰이어코리아', '커머스모델', '남자모델', '화보', '지면화보', '패션화보', '패션매거진']
# ========================================
# 106 ['에스콰이어코리아', '남성잡지', '2019may', '눈정화', '박서준님', '잘생기심', '울아들도', '저렇게컸으면', '존잘남']
# ========================================
# 107 ['에스콰이어', '에스콰이어코리아', '나인오파이브', '볼캡', 'nin905ive', '류준열', '모자', '잡지', 'esquire', 'esquirekorea', 'cap', 'fashion', '코디', '패션', 'thisisneverthat', 'nike', 'calvinkleinjeans']
# ========================================
# 108 ['류준열', 'RyuJunYeol', '柳俊烈', 'リュジュンヨル', '류스타그램', 'PoloRalphLauren', '폴로랄프로렌', 'TheEarthPolo', '에스콰이어코리아', '에스콰이어', 'esquirekorea', '에스콰이어6월호', 'coverstory', '여름준열']
# ========================================
# 109 ['에스콰이어코리아', '몽블랑시계', '리즈앤에이미', '케이터링']
# ========================================
# 110 ['에스콰이어코리아', '몽블랑시계', '리즈앤에이미', '케이터링']
# ========================================
# 111 ['에스콰이어', '에스콰이어코리아', '에스콰이어6월호', '류준열', '준열', '류준열배우', '류준열배우님', '캘리그라피', '캘리그래피', '캘리', '캘스타그램', '캘리그라피연습', '캘리그라피독학', '디지털캘리', '디지털캘리그라피', '손글씨', '세영쓰다']
# ========================================
# 112 ['이서진', 'LeeSeoJin', '李瑞鎮', '李瑞镇', 'ソジン', 'Bvlgari', '불가리', 'esquirekorea', '에스콰이어코리아']
# ========================================
# 113 ['이서진', 'LeeSeoJin', '李瑞鎮', '李瑞镇', 'ソジン', 'Bvlgari', '불가리', 'esquirekorea', '에스콰이어코리아']
# ========================================
# 114 ['Repost', '류준열', 'RyuJunYeol', '柳俊烈', 'リュジュンヨル', '류스타그램', '에스콰이어코리아', 'coverstory', 'RyuJunYeol', '류준열', 'PoloRalphLauren', '폴로랄프로렌', 'TheEarthPolo', '에스콰이어', 'esquirekorea']
# ========================================
# 115 ['류준열', '에스콰이어', 'esquire', '에스콰이어코리아', 'esquirekorea']
# ========================================
# 116 ['류준열']
# ========================================
# 117 ['류준열', 'RyuJunYeol', '柳俊烈', 'リュジュンヨル', '에스콰이어코리아', '에스콰이어6월호', 'Esquirekorea', '여름준열']
# ========================================
# 118 ['류준열', 'RyuJunYeol', '柳俊烈', 'リュジュンヨル', '에스콰이어코리아', '에스콰이어6월호', 'Esquirekorea', '여름준열']
# ========================================
# 119 ['이서진', 'LeeSeoJin', '李瑞鎮', '李瑞镇', 'ソジン', 'Bvlgari', '불가리', 'esquirekorea', '에스콰이어코리아']
# ========================================
# 120 ['류준열', '에스콰이어코리아', '6월호', '류준열의매력은어디까지', '무궁무진']
# ========================================
# 121 ['류준열', 'RyuJunYeol', '柳俊烈', 'リュジュンヨル', '에스콰이어코리아', '에스콰이어6월호', 'Esquirekorea', '여름준열']
# ========================================
# 122 ['에스콰이어', 'esquire', '에스콰이어코리아', 'esquirekorea']
# ========================================
# 123 ['에스콰이어코리아', 'esquirekorea', '잡지', '편집디자인', '그래픽디자인', '화보', '카탈로그', '사보', '출판', '독립출판', '인쇄', '단행본', 'magazine', 'editorialdesign', 'graphicdesign', 'printdesign', 'pictorial', 'artdirection', 'layout', 'typo', 'poster', '패션', 'fashion', '자동차', 'car', '시계', 'watch']
# ========================================
# out
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-784399775e60> in <module>
#      34             print("="*40)
# ---> 35             sleep(1.5)
#      36             # 본문 읽어오기
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-4-784399775e60> in <module>
#      43         except:
#      44             print('out')
# ---> 45             driver.close()
#      46             break;
#
# /anaconda3/envs/azmo_dev/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     677             driver.close()
#     678         """
# --> 679         self.execute(Command.CLOSE)
#     680
#     681     def quit(self):
#
# /anaconda3/envs/azmo_dev/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     308
#     309         params = self._wrap_value(params)
# --> 310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
#     312             self.error_handler.check_response(response)
#
# /anaconda3/envs/azmo_dev/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     464         data = utils.dump_json(params)
#     465         url = '%s%s' % (self._url, path)
# --> 466         return self._request(command_info[0], url, body=data)
#     467
#     468     def _request(self, method, url, body=None):
#
# /anaconda3/envs/azmo_dev/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     488             try:
#     489                 self._conn.request(method, parsed_url.path, body, headers)
# --> 490                 resp = self._conn.getresponse()
#     491             except (httplib.HTTPException, socket.error):
#     492                 self._conn.close()
#
# /anaconda3/envs/azmo_dev/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/envs/azmo_dev/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/envs/azmo_dev/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/envs/azmo_dev/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ConnectionResetError: [Errno 54] Connection reset by peer
